# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/data of shoolini/Cars Dataset.csv')

# %%
df
# Out:
#                   Model    Year    Km/h      Color       Type      Fuel  \
# 0    Hyundai Elantra HD  2009.0  165,000      Gray  Automatic  Gasoline
# 1       Hyundai Elantra  2010.0  194,000     Black  Automatic  Gasoline
# 2    Hyundai Elantra HD  2010.0  205,000    Silver  Automatic  Gasoline
# 3       Hyundai Elantra  2010.0  160,000     Black  Automatic  Gasoline
# 4       Hyundai Elantra  2009.0  140,451  Eggplant  Automatic  Gasoline
# ..                  ...     ...      ...       ...        ...       ...
# 952                 NaN     NaN      NaN       NaN        NaN       NaN
# 953                 NaN     NaN      NaN       NaN        NaN       NaN
# 954                 NaN     NaN      NaN       NaN        NaN       NaN
# 955                 NaN     NaN      NaN       NaN        NaN       NaN
# 956                 NaN     NaN      NaN       NaN        NaN       NaN
#
#        Price
# 0    560,000
# 1    600,000
# 2    575,000
# 3    550,000
# 4    650,000
# ..       ...
# ...

# %%
df.head(2)
# Out:
#                 Model    Year    Km/h   Color       Type      Fuel    Price
# 0  Hyundai Elantra HD  2009.0  165,000   Gray  Automatic  Gasoline  560,000
# 1     Hyundai Elantra  2010.0  194,000  Black  Automatic  Gasoline  600,000

# %%
df.tail(5)
# Out:
#     Model  Year  Km/h  Color Type Fuel Price
# 952   NaN   NaN    NaN   NaN  NaN  NaN   NaN
# 953   NaN   NaN    NaN   NaN  NaN  NaN   NaN
# 954   NaN   NaN    NaN   NaN  NaN  NaN   NaN
# 955   NaN   NaN    NaN   NaN  NaN  NaN   NaN
# 956   NaN   NaN    NaN   NaN  NaN  NaN   NaN

# %%
df.isnull().sum()
# Out:
# Model     358
# Year      358
#  Km/h     358
# Color     358
# Type      358
# Fuel      358
# Price     358
# dtype: int64

# %%
df.dropna()
# Out:
#                           Model    Year    Km/h      Color       Type  \
# 0            Hyundai Elantra HD  2009.0  165,000      Gray  Automatic
# 1               Hyundai Elantra  2010.0  194,000     Black  Automatic
# 2            Hyundai Elantra HD  2010.0  205,000    Silver  Automatic
# 3               Hyundai Elantra  2010.0  160,000     Black  Automatic
# 4               Hyundai Elantra  2009.0  140,451  Eggplant  Automatic
# ..                          ...     ...      ...       ...        ...
# 594                 KIA Picanto  2015.0   70,000    Silver  Automatic
# 595  Mitsubishi Lancer EX Shark  2015.0  120,000     Black  Automatic
# 596           Ssang Yong Torres  2024.0    4,000     White  Automatic
# 597                  KIA Cerato  2011.0  200,000       Red  Automatic
# 598          Hyundai Elantra HD  2020.0   80,000    Bronze  Automatic
#
#          Fuel      Price
# 0    Gasoline    560,000
# 1    Gasoline    600,000
# 2    Gasoline    575,000
# ...

# %%
df.isnull().sum()
# Out:
# Model     358
# Year      358
#  Km/h     358
# Color     358
# Type      358
# Fuel      358
# Price     358
# dtype: int64

# %%
df.dropna()
# Out:
#                           Model    Year    Km/h      Color       Type  \
# 0            Hyundai Elantra HD  2009.0  165,000      Gray  Automatic
# 1               Hyundai Elantra  2010.0  194,000     Black  Automatic
# 2            Hyundai Elantra HD  2010.0  205,000    Silver  Automatic
# 3               Hyundai Elantra  2010.0  160,000     Black  Automatic
# 4               Hyundai Elantra  2009.0  140,451  Eggplant  Automatic
# ..                          ...     ...      ...       ...        ...
# 594                 KIA Picanto  2015.0   70,000    Silver  Automatic
# 595  Mitsubishi Lancer EX Shark  2015.0  120,000     Black  Automatic
# 596           Ssang Yong Torres  2024.0    4,000     White  Automatic
# 597                  KIA Cerato  2011.0  200,000       Red  Automatic
# 598          Hyundai Elantra HD  2020.0   80,000    Bronze  Automatic
#
#          Fuel      Price
# 0    Gasoline    560,000
# 1    Gasoline    600,000
# 2    Gasoline    575,000
# ...

# %%
df.columns
# Out:
# Index(['Model', 'Year', ' Km/h ', 'Color', 'Type', 'Fuel', 'Price'], dtype='object')

# %%
df.dropna(inplace = True)

# %%
df['Price'] = df['Price'].str.replace(',', '').astype(int)

# %%
df[' Km/h '] = df[' Km/h '].str.replace(',', '').astype(int)

# %%
x = df.iloc[:, 1:3 ]

# %%
x
# Out:
#        Year   Km/h
# 0    2009.0  165000
# 1    2010.0  194000
# 2    2010.0  205000
# 3    2010.0  160000
# 4    2009.0  140451
# ..      ...     ...
# 594  2015.0   70000
# 595  2015.0  120000
# 596  2024.0    4000
# 597  2011.0  200000
# 598  2020.0   80000
#
# [599 rows x 2 columns]

# %%
y = df.iloc[:, -1]

# %%
y
# Out:
# 0       560000
# 1       600000
# 2       575000
# 3       550000
# 4       650000
#         ...
# 594     535000
# 595     660000
# 596    1900000
# 597     665000
# 598     700000
# Name: Price, Length: 599, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
x_train
# Out:
#        Year   Km/h
# 145  2017.0  130000
# 9    2009.0  100000
# 375  2014.0  155227
# 522  2019.0   41000
# 188  2016.0  130000
# ..      ...     ...
# 71   2012.0  200000
# 106  2021.0   45000
# 270  2022.0     125
# 435  2023.0  135000
# 102  2023.0   62000
#
# [479 rows x 2 columns]

# %%
x_train
# Out:
#        Year   Km/h
# 145  2017.0  130000
# 9    2009.0  100000
# 375  2014.0  155227
# 522  2019.0   41000
# 188  2016.0  130000
# ..      ...     ...
# 71   2012.0  200000
# 106  2021.0   45000
# 270  2022.0     125
# 435  2023.0  135000
# 102  2023.0   62000
#
# [479 rows x 2 columns]

# %%
y_train
# Out:
# 145    1750000
# 9       475000
# 375    1020000
# 522    1200000
# 188     740000
#         ...
# 71      875000
# 106    1000000
# 270    1149000
# 435    2270000
# 102    1870000
# Name: Price, Length: 479, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
m = model.coef_
c = model.intercept_

# %%
m1 = m[0]
print(m1)
# Out:
# 96.50362950454169

# %%
m2 = m[1]
print(m2)
# Out:
# -5.86890820937947

# %%
price = m1*2019+m2*210000 +c
print(price)
# Out:
# 682383.6140385737

# %%
price = m1*2010+m2*110000 +c
print(price)
# Out:
# 1268405.90231098

# %%
price = m1*2015+m2*70000+c
print(price)
# Out:
# 1503644.7488336815

# %%
price = m1*2026+m2*0+c
print(c)
# Out:
# 1720013.5100385929
